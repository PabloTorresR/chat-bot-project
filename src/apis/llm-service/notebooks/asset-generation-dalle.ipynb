# %% [markdown]
# # Generate assets using DALL-E

# %%
from openai import OpenAI

client = OpenAI()

app_style = """In style that is vibrant, flat, vector-art. Use a bold, bright color palette with teal, purple, yellow and pink. The overall aesthetic is cyberpunk, with clean lines, simple and sharp geometric shapes, and minimal shading. Ensure the lines are sharp and clean, no round edges, with minimal shading."""

response = client.images.generate(
    model="dall-e-3",
    prompt=app_style
    + " Logo of my language learning app. The logo is a MONOCHROME MINIMALISTIC ONE ELEMENT komodo dragon head. Will be used mainly in dark background",
    size="1024x1024",
    quality="standard",
    n=1,
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[18], line 7
#       3 client = OpenAI()
#       5 app_style = """In style that is vibrant, flat, vector-art. Use a bold, bright color palette with teal, purple, yellow and pink. The overall aesthetic is cyberpunk, with clean lines, simple and sharp geometric shapes, and minimal shading. Ensure the lines are sharp and clean, no round edges, with minimal shading."""
# ----> 7 response = client.images.generate(
#       8     model="dall-e-3",
#       9     prompt=app_style
#      10     + " Logo of my language learning app. The logo is a MONOCHROME MINIMALISTIC ONE ELEMENT komodo dragon head. Will be used mainly in dark background",
#      11     size="512x512",
#      12     quality="standard",
#      13     n=1,
#      14 )
#
# ...

# %%
print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-4RCfoLGO5p9ZZsdJrQOnHnem/user-xgDgVceLn0IXkQ9J6NSOeLAV/img-lurz4lH7pcO4kCTAXtZcr2Cx.png?st=2024-09-21T20%3A51%3A37Z&se=2024-09-21T22%3A51%3A37Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-20T23%3A13%3A47Z&ske=2024-09-21T23%3A13%3A47Z&sks=b&skv=2024-08-04&sig=Ba7fQVPoen8jg%2B6g6kUKvCaSXCTwanEGpDe9tOyDE8A%3D
